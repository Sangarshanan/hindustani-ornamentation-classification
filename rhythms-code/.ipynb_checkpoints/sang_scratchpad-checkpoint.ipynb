# %%
from validate_ornamentations import validate_ornamentations

# %%
validate_ornamentations(num_to_show=10)
# Out:
# Loading track 66_Aahir_Bhairon...
# Loading annotations from Ornamentation-In-Hindustani-Vocals-Dataset/AahirBhairon_av.csv...
# Loading pitch data from /Users/sangarshananveera/Downloads/Datasets/saraga1.5_hindustani/Geetinandan : Part-3 by Ajoy Chakrabarty/Aahir Bhairon/Aahir Bhairon.pitch.txt...
# Loading audio from /Users/sangarshananveera/Downloads/Datasets/saraga1.5_hindustani/Geetinandan : Part-3 by Ajoy Chakrabarty/Aahir Bhairon/Aahir Bhairon.mp3.mp3...
#
# Showing first 10 ornamentations:
#
# Ornamentation 1: me | Start: 2.93s | End: 4.02s | Duration: 1.09s
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# --------------------------------------------------------------------------------
# Ornamentation 2: me | Start: 4.39s | End: 4.92s | Duration: 0.53s
# ...
